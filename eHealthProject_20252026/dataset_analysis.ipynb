# %%
#libraries
#ciao
import pandas as pd 
import numpy as np
import pip
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %%
path = "/Users/mirandadifrancesco/Desktop/progetto/eHealthProject_20252026/dataset_project_eHealth20252026.csv"
dataset = pd.read_csv(path)
dataset.head(5)
# Out:
#     age  gender  education  marital  income  audit_1  audit_2  audit_3  \
# 0  39.0       0        8.0      1.0   14000        4        3      0.0
# 1  18.0       1        5.0      1.0   25000        4        4      0.0
# 2  40.0       0       13.0      2.0   56000        0        0      0.0
# 3  24.0       1       22.0      0.0   35000        1        0      1.0
# 4  19.0       1       22.0      1.0   42000        2        2      0.0
#
#    audit_4  audit_5  ...  swls_1  swls_2  swls_3  swls_4  swls_5  who5_1  \
# 0        0      4.0  ...       2     0.0     4.0     2.0       0     2.0
# 1        0      0.0  ...       0     4.0     2.0     4.0       4     0.0
# 2        0      0.0  ...       0     2.0     4.0     0.0       2     3.0
# 3        1      1.0  ...       2     2.0     4.0     3.0       4     3.0
# 4        2      2.0  ...       5     7.0     3.0     5.0       7     5.0
#
#    who5_2  who5_3  who5_4  who5_5
# 0       3     3.0     3.0     2.0
# 1       0     3.0     2.0     2.0
# 2       2     3.0     2.0     3.0
# 3       2     1.0     2.0     3.0
# 4       5     4.0     3.0     3.0
#
# [5 rows x 96 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 96 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        220 non-null    float64
#  1   gender     221 non-null    int64
#  2   education  220 non-null    float64
#  3   marital    220 non-null    float64
#  4   income     221 non-null    int64
#  5   audit_1    221 non-null    int64
#  6   audit_2    221 non-null    int64
#  7   audit_3    220 non-null    float64
#  8   audit_4    221 non-null    int64
#  9   audit_5    220 non-null    float64
#  10  audit_6    221 non-null    int64
#  11  audit_7    220 non-null    float64
#  12  audit_8    220 non-null    float64
#  13  audit_9    220 non-null    float64
#  14  audit_10   219 non-null    float64
#  15  dast_1     221 non-null    int64
#  16  dast_2     219 non-null    float64
#  17  dast_3     220 non-null    float64
#  18  dast_4     221 non-null    int64
#  19  dast_5     220 non-null    float64
#  20  dast_6     220 non-null    float64
#  21  dast_7     219 non-null    float64
#  22  dast_8     221 non-null    int64
#  23  dast_9     219 non-null    float64
#  24  dast_10    219 non-null    float64
#  25  pgsi_1     220 non-null    float64
#  26  pgsi_2     221 non-null    int64
#  27  pgsi_3     220 non-null    float64
#  28  pgsi_4     221 non-null    int64
#  29  pgsi_5     221 non-null    int64
#  30  pgsi_6     218 non-null    float64
#  31  pgsi_7     221 non-null    int64
#  32  pgsi_8     221 non-null    int64
#  33  pgsi_9     221 non-null    int64
#  34  iat_1      220 non-null    float64
#  35  iat_2      221 non-null    int64
#  36  iat_3      218 non-null    float64
#  37  iat_4      221 non-null    int64
#  38  iat_5      220 non-null    float64
#  39  iat_6      220 non-null    float64
#  40  iat_7      219 non-null    float64
#  41  iat_8      219 non-null    float64
#  42  iat_9      221 non-null    int64
#  43  iat_10     220 non-null    float64
#  44  iat_11     221 non-null    int64
#  45  iat_12     221 non-null    int64
#  46  iat_13     221 non-null    int64
#  47  iat_14     220 non-null    float64
#  48  iat_15     221 non-null    int64
#  49  iat_16     221 non-null    int64
#  50  iat_17     220 non-null    float64
#  51  iat_18     221 non-null    int64
#  52  iat_19     221 non-null    int64
#  53  iat_20     221 non-null    int64
#  54  pcl5_1     221 non-null    int64
#  55  pcl5_2     219 non-null    float64
#  56  pcl5_3     221 non-null    int64
#  57  pcl5_4     220 non-null    float64
#  58  pcl5_5     221 non-null    int64
#  59  pcl5_6     218 non-null    float64
#  60  pcl5_7     218 non-null    float64
#  61  pcl5_8     221 non-null    int64
#  62  pcl5_9     221 non-null    int64
#  63  pcl5_10    220 non-null    float64
#  64  pcl5_11    221 non-null    int64
#  65  pcl5_12    220 non-null    float64
#  66  pcl5_13    219 non-null    float64
#  67  pcl5_14    221 non-null    int64
#  68  pcl5_15    221 non-null    int64
#  69  pcl5_16    220 non-null    float64
#  70  pcl5_17    221 non-null    int64
#  71  pcl5_18    220 non-null    float64
#  72  pcl5_19    221 non-null    int64
#  73  pcl5_20    221 non-null    int64
#  74  mspss_1    220 non-null    float64
#  75  mspss_2    221 non-null    int64
#  76  mspss_3    220 non-null    float64
#  77  mspss_4    220 non-null    float64
#  78  mspss_5    218 non-null    float64
#  79  mspss_6    219 non-null    float64
#  80  mspss_7    218 non-null    float64
#  81  mspss_8    220 non-null    float64
#  82  mspss_9    219 non-null    float64
#  83  mspss_10   220 non-null    float64
#  84  mspss_11   221 non-null    int64
#  85  mspss_12   219 non-null    float64
#  86  swls_1     221 non-null    int64
#  87  swls_2     220 non-null    float64
#  88  swls_3     220 non-null    float64
#  89  swls_4     220 non-null    float64
#  90  swls_5     221 non-null    int64
#  91  who5_1     220 non-null    float64
#  92  who5_2     221 non-null    int64
#  93  who5_3     220 non-null    float64
#  94  who5_4     219 non-null    float64
#  95  who5_5     219 non-null    float64
# dtypes: float64(54), int64(42)
# memory usage: 165.9 KB

# %%
df = pd.DataFrame(dataset) #dataframe creation

# %%
df.duplicated() #check for duplicated rows and delete them
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 216     True
# 217     True
# 218     True
# 219     True
# 220     True
# Length: 221, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       age  gender  education  marital  income  audit_1  audit_2  audit_3  \
# 0    39.0       0        8.0      1.0   14000        4        3      0.0
# 1    18.0       1        5.0      1.0   25000        4        4      0.0
# 2    40.0       0       13.0      2.0   56000        0        0      0.0
# 3    24.0       1       22.0      0.0   35000        1        0      1.0
# 4    19.0       1       22.0      1.0   42000        2        2      0.0
# ..    ...     ...        ...      ...     ...      ...      ...      ...
# 195  28.0       0       13.0      1.0   36000        1        1      0.0
# 196  21.0       0       18.0      1.0   38000        1        1      1.0
# 197  20.0       1       22.0      4.0   50000        2        2      0.0
# 198  39.0       0        8.0      1.0   22000        0        4      3.0
# 199  32.0       1       13.0      2.0   37800        1        0      1.0
#
#      audit_4  audit_5  ...  swls_1  swls_2  swls_3  swls_4  swls_5  who5_1  \
# 0          0      4.0  ...       2     0.0     4.0     2.0       0     2.0
# 1          0      0.0  ...       0     4.0     2.0     4.0       4     0.0
# 2          0      0.0  ...       0     2.0     4.0     0.0       2     3.0
# 3          1      1.0  ...       2     2.0     4.0     3.0       4     3.0
# 4          2      2.0  ...       5     7.0     3.0     5.0       7     5.0
# ..       ...      ...  ...     ...     ...     ...     ...     ...     ...
# 195        0      0.0  ...       4     1.0     4.0     0.0       0     0.0
# 196        0      1.0  ...       4     4.0     4.0     4.0       3     3.0
# 197        2      1.0  ...       7     7.0     7.0     1.0       7     3.0
# 198        2      0.0  ...       0     4.0     4.0     4.0       1     1.0
# 199        1      1.0  ...       0     3.0     4.0     0.0       3     0.0
#
#      who5_2  who5_3  who5_4  who5_5
# 0         3     3.0     3.0     2.0
# 1         0     3.0     2.0     2.0
# 2         2     3.0     2.0     3.0
# 3         2     1.0     2.0     3.0
# 4         5     4.0     3.0     3.0
# ..      ...     ...     ...     ...
# 195       3     3.0     3.0     1.0
# 196       3     2.0     0.0     3.0
# 197       5     5.0     5.0     3.0
# 198       0     3.0     2.0     0.0
# 199       3     3.0     3.0     1.0
#
# [200 rows x 96 columns]

# %%
sns.histplot(data=df, x='age', binwidth=1, palette=['blue']).set_title(f"Histogram of age")
plt.show()
# Out:
# /var/folders/03/kf4b2yc11090vt24qbw0y5y00000gn/T/ipykernel_44900/4077314633.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x='age', binwidth=1, palette=['blue']).set_title(f"Histogram of age")

# %%
#[0] Male [1] Female [2] Non-binary [3] Prefer not to say

# Replace numeric codes with labels
gender_labels = {
    0: 'Male',
    1: 'Female',
    2: 'Non-binary',
    3: 'Prefer not to say'
}
df['gender_label'] = df['gender'].map(gender_labels)

# Plot
sns.countplot(data=df, x='gender_label', color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Subjects')
plt.title('Gender Distribution')
plt.xticks(rotation=15)
plt.show()

# %%
#[5] Elementary school [8] Middle school [13] High School [18]Bachelor's Degree [22] Master's Degree [25] Doctoral Degree

# Replace numeric codes with labels
school_labels = {
    5: 'Elementary',
    8: 'Middle',
    13: 'High',
    18: 'Bachelor',
    22: 'Master',
    25: 'Doctoral'
}
df['school_labels'] = df['education'].map(school_labels)

# Plot
sns.countplot(data=df, x='school_labels', color='skyblue')
plt.xlabel('School')
plt.ylabel('Subjects')
plt.title('Education Distribution')
plt.xticks(rotation=15)
plt.show()

# %%
#[5] [0] Single [1] Married [2] Divorced [3] Widowed [4] Separated [5] Prefer not to say

# Replace numeric codes with labels
marital_labels = {
    0: 'Single',
    1: 'Married',
    2: 'Divorced',
    3: 'Widowed',
    4: 'Separated',
    5: 'Prefer not to say'
}
df['marital_labels'] = df['marital'].map(marital_labels)

# Plot
sns.countplot(data=df, x='marital_labels', color='skyblue')
plt.xlabel('Marital')
plt.ylabel('Subjects')
plt.title('Marital Distribution')
plt.xticks(rotation=15)
plt.show()

# %%
# in order to focus on internet addiction, let's drop out all the indices related to other addictions:
# dropped columns --> AUDIT (Alcohol Use Disorders Identification Test), DAST (Drug Abuse Screening Test), PGSI (Problem Gambling Severity Index), 
# maintained cols --> PCL-5 (PTSD Checklist for DSM-5), MSPSS (Multidimensional Scale of Perceived Social Support), SWLS (Satisfaction With Life Scale), WHO-5 (Well-Being Index)

# Identify columns related to AUDIT, DAST, and PGSI
cols_to_remove = [col for col in df.columns if col.lower().startswith(('audit','dast','pgsi','gender_label','school_label','marital_labels'))]

# Drop those columns
df_filtered = df.drop(columns=cols_to_remove)

# Save cleaned dataset
# df_filtered.to_csv('dataset_eHealth20252026_noAUDIT_DAST_PGSI.csv', index=False)

# %%
df
# Out:
#       age  gender  education  marital  income  audit_1  audit_2  audit_3  \
# 0    39.0       0        8.0      1.0   14000        4        3      0.0
# 1    18.0       1        5.0      1.0   25000        4        4      0.0
# 2    40.0       0       13.0      2.0   56000        0        0      0.0
# 3    24.0       1       22.0      0.0   35000        1        0      1.0
# 4    19.0       1       22.0      1.0   42000        2        2      0.0
# ..    ...     ...        ...      ...     ...      ...      ...      ...
# 216  39.0       1       13.0      5.0   45000        2        1      2.0
# 217  20.0       1        5.0      1.0   21000        3        1      3.0
# 218  21.0       1        8.0      5.0   24000        1        0      1.0
# 219  40.0       0        5.0      0.0   22000        3        4      4.0
# 220  38.0       0        5.0      0.0   24000        4        3      3.0
#
#      audit_4  audit_5  ...  swls_4  swls_5  who5_1  who5_2  who5_3  who5_4  \
# 0          0      4.0  ...     2.0       0     2.0       3     3.0     3.0
# 1          0      0.0  ...     4.0       4     0.0       0     3.0     2.0
# 2          0      0.0  ...     0.0       2     3.0       2     3.0     2.0
# 3          1      1.0  ...     3.0       4     3.0       2     1.0     2.0
# 4          2      2.0  ...     5.0       7     5.0       5     4.0     3.0
# ..       ...      ...  ...     ...     ...     ...     ...     ...     ...
# 216        2      2.0  ...     6.0       7     4.0       5     5.0     3.0
# 217        3      1.0  ...     1.0       0     1.0       2     3.0     2.0
# 218        1      1.0  ...     6.0       1     3.0       4     0.0     5.0
# 219        0      2.0  ...     4.0       4     0.0       3     1.0     0.0
# 220        4      0.0  ...     0.0       4     3.0       1     3.0     0.0
#
#      who5_5  gender_label  school_labels     marital_labels
# 0       2.0          Male         Middle            Married
# 1       2.0        Female     Elementary            Married
# 2       3.0          Male           High           Divorced
# 3       3.0        Female         Master             Single
# 4       3.0        Female         Master            Married
# ..      ...           ...            ...                ...
# 216     5.0        Female           High  Prefer not to say
# 217     3.0        Female     Elementary            Married
# 218     5.0        Female         Middle  Prefer not to say
# 219     2.0          Male     Elementary             Single
# 220     3.0          Male     Elementary             Single
#
# [221 rows x 99 columns]

# %%
df_filtered
# Out:
#       age  gender  education  marital  income  iat_1  iat_2  iat_3  iat_4  \
# 0    39.0       0        8.0      1.0   14000    2.0      3    3.0      3
# 1    18.0       1        5.0      1.0   25000    3.0      3    3.0      1
# 2    40.0       0       13.0      2.0   56000    4.0      1    4.0      3
# 3    24.0       1       22.0      0.0   35000    4.0      4    0.0      0
# 4    19.0       1       22.0      1.0   42000    0.0      0    0.0      0
# ..    ...     ...        ...      ...     ...    ...    ...    ...    ...
# 216  39.0       1       13.0      5.0   45000    0.0      0    0.0      0
# 217  20.0       1        5.0      1.0   21000    3.0      0    2.0      3
# 218  21.0       1        8.0      5.0   24000    5.0      5    5.0      5
# 219  40.0       0        5.0      0.0   22000    2.0      3    NaN      3
# 220  38.0       0        5.0      0.0   24000    1.0      3    3.0      2
#
#      iat_5  ...  swls_1  swls_2  swls_3  swls_4  swls_5  who5_1  who5_2  \
# 0      2.0  ...       2     0.0     4.0     2.0       0     2.0       3
# 1      3.0  ...       0     4.0     2.0     4.0       4     0.0       0
# 2      4.0  ...       0     2.0     4.0     0.0       2     3.0       2
# 3      3.0  ...       2     2.0     4.0     3.0       4     3.0       2
# 4      0.0  ...       5     7.0     3.0     5.0       7     5.0       5
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 216    2.0  ...       5     7.0     6.0     6.0       7     4.0       5
# 217    3.0  ...       4     2.0     4.0     1.0       0     1.0       2
# 218    5.0  ...       5     6.0     6.0     6.0       1     3.0       4
# 219    2.0  ...       4     2.0     4.0     4.0       4     0.0       3
# 220    2.0  ...       4     1.0     4.0     0.0       4     3.0       1
#
#      who5_3  who5_4  who5_5
# 0       3.0     3.0     2.0
# 1       3.0     2.0     2.0
# 2       3.0     2.0     3.0
# 3       1.0     2.0     3.0
# 4       4.0     3.0     3.0
# ..      ...     ...     ...
# 216     5.0     3.0     5.0
# 217     3.0     2.0     3.0
# 218     0.0     5.0     5.0
# 219     1.0     0.0     2.0
# 220     3.0     0.0     3.0
#
# [221 rows x 67 columns]

# %%
from scipy.stats import shapiro

results = []
for i in range(1, 21):
    col = f'iat_{i}'
    data = df[col].dropna()
    stat, p = shapiro(data)
    results.append({'column': col, 'statistic': stat, 'p_value': p, 'alpha': 0.05, 'normal': p > 0.05})

result_df = pd.DataFrame(results)
result_df.to_csv('iat1to10_shapiro_results.csv', index=False)
result_df.head(10)
# Out:
#    column  statistic       p_value  alpha  normal
# 0   iat_1   0.902689  9.004394e-11   0.05   False
# 1   iat_2   0.901182  6.655353e-11   0.05   False
# 2   iat_3   0.892516  2.261891e-11   0.05   False
# 3   iat_4   0.883088  4.799112e-12   0.05   False
# 4   iat_5   0.901892  7.959547e-11   0.05   False
# 5   iat_6   0.894253  2.522048e-11   0.05   False
# 6   iat_7   0.880108  3.715548e-12   0.05   False
# 7   iat_8   0.891425  1.796825e-11   0.05   False
# 8   iat_9   0.877132  2.144801e-12   0.05   False
# 9  iat_10   0.863577  4.078388e-13   0.05   False

# %%
# generate gaussian data
import numpy as np
import scipy.stats as stats
import random
random.seed(42)

# generate univariate observations
data =  stats.norm(scale=1, loc=0).rvs(1000)

# summarize
print('mean=%.3f stdv=%.3f' % (np.mean(data), np.std(data)))

# %%
# Select only IAT columns
iat_cols = [col for col in df.columns if col.startswith('iat_')]
df_iat = df[iat_cols]

# Calculate the correlation matrix (default is Pearson, for non-parametric use df_iat.corr(method='spearman'))
corr_matrix = df_iat.corr(method='spearman')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Spearman Correlation Heatmap of IAT Columns")
plt.show()

# %% [markdown]
# Internal consistency and sum scores: Internal consistency indicates that the individual items (or components) of a test or dataset are reliably measuring the same thing.
# For this reason, we can compute the sum and the mean as representative values of all the iat which are present in the dataset.

# %%
#https://how.dev/answers/how-to-implement-cronbachs-alpha-for-reliability-in-python
def cronbach_alpha(data):
    # Transform the data frame into a correlation matrix
    df_corr = data.corr()
    
    # Calculate N
    # The number of variables is equal to the number of columns in the dataframe
    N = data.shape[1]
    
    # Calculate r
    # For this, we'll loop through all the columns and append every
    # relevant correlation to an array called 'r_s'. Then, we'll
    # calculate the mean of 'r_s'.
    rs = np.array([])
    for i, col in enumerate(df_corr.columns):
        sum_ = df_corr[col][i+1:].values
        rs = np.append(sum_, rs)
    mean_r = np.mean(rs)
    
   # Use the formula to calculate Cronbach's Alpha 
    cronbach_alpha = (N * mean_r) / (1 + (N - 1) * mean_r)
    return cronbach_alpha
# Calling function to the calculate value of Cronbach's alpha
cronbach_alpha(df_iat)
# Out:
# np.float64(0.9735342286149691)

# %%
#specify the columns to sum
cols_to_sum = [col for col in df_filtered.columns if col.lower().startswith(('iat'))]

#define new column that contains sum of specific columns
df_filtered['sum_iat'] = df_filtered[cols_to_sum].sum(axis=1)
df_filtered['mean_iat'] = df_filtered[cols_to_sum].mean(axis=1)

#view updated DataFrame
df_filtered
# Out:
#       age  gender  education  marital  income  iat_1  iat_2  iat_3  iat_4  \
# 0    39.0       0        8.0      1.0   14000    2.0      3    3.0      3
# 1    18.0       1        5.0      1.0   25000    3.0      3    3.0      1
# 2    40.0       0       13.0      2.0   56000    4.0      1    4.0      3
# 3    24.0       1       22.0      0.0   35000    4.0      4    0.0      0
# 4    19.0       1       22.0      1.0   42000    0.0      0    0.0      0
# ..    ...     ...        ...      ...     ...    ...    ...    ...    ...
# 216  39.0       1       13.0      5.0   45000    0.0      0    0.0      0
# 217  20.0       1        5.0      1.0   21000    3.0      0    2.0      3
# 218  21.0       1        8.0      5.0   24000    5.0      5    5.0      5
# 219  40.0       0        5.0      0.0   22000    2.0      3    NaN      3
# 220  38.0       0        5.0      0.0   24000    1.0      3    3.0      2
#
#      iat_5  ...  swls_3  swls_4  swls_5  who5_1  who5_2  who5_3  who5_4  \
# 0      2.0  ...     4.0     2.0       0     2.0       3     3.0     3.0
# 1      3.0  ...     2.0     4.0       4     0.0       0     3.0     2.0
# 2      4.0  ...     4.0     0.0       2     3.0       2     3.0     2.0
# 3      3.0  ...     4.0     3.0       4     3.0       2     1.0     2.0
# 4      0.0  ...     3.0     5.0       7     5.0       5     4.0     3.0
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 216    2.0  ...     6.0     6.0       7     4.0       5     5.0     3.0
# 217    3.0  ...     4.0     1.0       0     1.0       2     3.0     2.0
# 218    5.0  ...     6.0     6.0       1     3.0       4     0.0     5.0
# 219    2.0  ...     4.0     4.0       4     0.0       3     1.0     0.0
# 220    2.0  ...     4.0     0.0       4     3.0       1     3.0     0.0
#
#      who5_5  sum_iat  mean_iat
# 0       2.0     39.0  1.950000
# 1       2.0     33.0  1.650000
# 2       3.0     60.0  3.000000
# 3       3.0     56.0  2.800000
# 4       3.0      0.0  0.000000
# ..      ...      ...       ...
# 216     5.0      6.0  0.300000
# 217     3.0     40.0  2.000000
# 218     5.0    100.0  5.000000
# 219     2.0     29.0  1.526316
# 220     3.0     33.0  1.650000
#
# [221 rows x 69 columns]

# %%
#Total scores that range from 0 to 30 points are considered to reflect a normal level of Internet usage; 
#scores of 31 to 49 indicate the presence of a mild level of Internet addiction; 
#50 to 79 reflect the presence of a moderate level;
#scores of 80 to 100 indicate a severe dependence upon the Internet.

# Define addiction levels based on sum_iat cut-offs
def classify_iat(total):
    if total <= 30:
        return 'Normal'
    elif total <= 49:
        return 'Mild'
    elif total <= 79:
        return 'Moderate'
    else:
        return 'Severe'

# Apply classification
df_filtered['addiction_level'] = df_filtered['sum_iat'].apply(classify_iat)
df_filtered

# Group and count occurrences
# Prepare data as DataFrame with explicit columns
order = ['Normal', 'Mild', 'Moderate', 'Severe']
grouped = df_filtered['addiction_level'].value_counts().reindex(order).fillna(0).reset_index() 
# reindex Ensures the Series is re-ordered to match your custom order list (['Normal', 'Mild', 'Moderate', 'Severe']). 
# fillna Replaces any missing counts from the reindex step with 0 (so missing groups show up as 0 instead of NaN).
# 
grouped.columns = ['addiction_level', 'count']

# Create the blue gradient palette and create the barplot
blue_palette = sns.color_palette("Blues", n_colors=4)

plt.figure(figsize=(7,5))
sns.barplot(
    data=grouped,
    x='addiction_level',
    y='count',
    hue='addiction_level',
    palette=blue_palette,
    dodge=False,       # Avoids stacked bars
    order=order,
    legend=False
)
plt.xlabel('Internet Addiction Level')
plt.ylabel('Count')
plt.title('Distribution of Internet Addiction Levels')
plt.tight_layout()

plt.show(), df_filtered['addiction_level'].value_counts()
# Out:
# (None,
#  addiction_level
#  Normal      57
#  Mild        55
#  Severe      55
#  Moderate    54
#  Name: count, dtype: int64)

# %% [markdown]
# Correlation between IAT and other indices

# %%
# Select specific columns
pcl5_cols = [col for col in df.columns if col.startswith('pcl5_')]
df_pcl5 = df[pcl5_cols]

mspss_cols = [col for col in df.columns if col.startswith('mspss_')]
df_mspss = df[mspss_cols]

swls_cols = [col for col in df.columns if col.startswith('swls_')]
df_swls = df[swls_cols]

who5_cols = [col for col in df.columns if col.startswith('who5_')]
df_who5 = df[who5_cols]

cronbach_alpha(df_pcl5), cronbach_alpha(df_mspss), cronbach_alpha(df_swls), cronbach_alpha(df_who5)
# Out:
# (np.float64(0.982044354982257),
#  np.float64(0.8789512278422936),
#  np.float64(0.7757240453135469),
#  np.float64(0.6140237349169649))

# %% [markdown]
# These results indicate strong internal consistency for the pcl5, mspss, and swls scales, and moderate consistency for who5. You can sum or average the items in each subscale as reference values for further analysis.

# %%
results_pcl5 = []
for i in range(1, 21):
    col = f'pcl5_{i}'
    data = df[col].dropna()
    stat, p = shapiro(data)
    results_pcl5.append({'column': col, 'statistic': stat, 'p_value': p, 'alpha': 0.05, 'normal': p > 0.05})

result_df = pd.DataFrame(results_pcl5)
result_df.to_csv('pcl51to20_shapiro_results.csv', index=False)
result_df.head(10)
# Out:
#     column  statistic       p_value  alpha  normal
# 0   pcl5_1   0.671860  1.808626e-20   0.05   False
# 1   pcl5_2   0.643507  3.700648e-21   0.05   False
# 2   pcl5_3   0.636243  1.915165e-21   0.05   False
# 3   pcl5_4   0.672852  2.143142e-20   0.05   False
# 4   pcl5_5   0.666840  1.303775e-20   0.05   False
# 5   pcl5_6   0.654558  8.184031e-21   0.05   False
# 6   pcl5_7   0.680987  4.525744e-20   0.05   False
# 7   pcl5_8   0.660249  8.531291e-21   0.05   False
# 8   pcl5_9   0.667447  1.356204e-20   0.05   False
# 9  pcl5_10   0.644228  3.474148e-21   0.05   False

# %%
# Calculate the correlation matrix (default is Pearson, for non-parametric use df_iat.corr(method='spearman'))
corr_matrix_pcl5 = df_pcl5.corr(method='spearman')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_pcl5, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Spearman Correlation Heatmap of PCL5 Columns")
plt.show()

# %%
# Calculate the correlation matrix (default is Pearson, for non-parametric use df_iat.corr(method='spearman'))
corr_matrix_mspss = df_mspss.corr(method='spearman')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_mspss, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Spearman Correlation Heatmap of PCL5 Columns")
plt.show()

# %%
# Calculate the correlation matrix (default is Pearson, for non-parametric use df_iat.corr(method='spearman'))
corr_matrix_mspss = df_mspss.corr(method='spearman')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_mspss, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Spearman Correlation Heatmap of PCL5 Columns")
plt.show()

# %%
df_mspss = df[mspss_cols]

df_swls = df[swls_cols]

df_who5 = df[who5_cols]
